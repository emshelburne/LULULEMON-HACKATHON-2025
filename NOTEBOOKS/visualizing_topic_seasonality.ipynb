# %% [markdown]
# # Visualizing Topic Seasonality

# %% [markdown]
# In this notebook, we create visualizations of the topics obtained by our BERTopic model. We examine how topics shift over time and season to season.

# %% [markdown]
# ## Preliminaries

# %%
# Imports

# General

import json
import math
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd

# Time / Grouping
from datetime import datetime, timezone, timedelta
import calendar

# BERTopic (load/use results)
from bertopic import BERTopic

# Plotting
import matplotlib.pyplot as plt             
import plotly.express as px           
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook"            # Set default plotly renderer

# ================== Utils ==================
from itertools import chain
from collections import Counter, defaultdict
import warnings, random
warnings.filterwarnings("ignore")
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %%
# Set user's data path

PATH = f"C:/Users/emshe/Desktop/BRAINSTATION/LULULEMON/DATA"

# %% [markdown]
# ## Helper functions

# %%
# Function to clean text

def clean_text(s: str | None) -> str | None:
    
    '''
    Clean string by substituting spaces for problematic characters
    '''
    
    if s is None:
        return None
    s = re.sub(r"\s+", " ", s).strip()
    return s

# %%
# Function to get datetime from UTC timestamp

def dt_from_epoch(ts: Optional[int]):

    """
    Convert timestamp to pd.datetime format
    """

    
    if ts is None:
        return None
    return pd.to_datetime(ts, unit="s", utc=True)

# %%
# Function to examine dataframes

def examine_df(name,df,
               include_stats = True,
               include_sample = True):
    
    """
    Check basic info about a dataframe df
    """
    
    print(f"\n\nNumber of records in the {name} is: {len(df)}\n")
    print(f"\nNumber of features in the {name} is: {len(df.columns)}\n")
    print(f"The columns in the {name} are: {df.columns}\n")
    print(f"\n Other info about {name}:\n")
    display(df.info())
    if include_stats == True:
        print(f'\n Basic statistical info about {name}:\n')
        display(df.describe())
    if include_sample == True:
        print(f"\n\nSample of records in the {name}:")
        display(df.head(5))

# %%
# Function to get sample from text column

def get_text_samples(df: pd.DataFrame, text_col: str, n: int) -> None:

    '''
    Print n samples from a text column in a dataframe
    '''

    # Ensure pandas doesn't truncate text
    pd.set_option('display.max_colwidth', None)
    
    # Sample and print 5 full negative reviews
    print("Sample text data:\n\n")
    sample = df[text_col].sample(n)
    for i, description in enumerate(sample, 1):
        print(f"Text sample {i}:\n\n\n{description}\n\n\n")

# %%
# Function for categorical bar graph

def bar_graph(df: pd.DataFrame, col: str) -> None:

    """
    Generate bar graph for categorical column in a dataframe
    """

    if col not in df.columns:
        raise ValueError(f"Column '{col}' not found in dataframe")

    counts = posts_df[col].value_counts()
    
    plt.figure(figsize=(10,6))
    counts.plot(kind="bar")
    plt.title(f"Distribution of {col.title()}")
    plt.xlabel(f"{col.title()}")
    plt.ylabel("Count")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %%
# Define function to plot histogram for numeric columns

def histogram(df: pd.DataFrame, 
             col: str,
            bins: int = 30,
             log: bool = False) -> None:
    
    """
    Generate a histogram for a numeric column in a dataframe.
    """
    
    if col not in df.columns:
        raise ValueError(f"Column '{col}' not found in dataframe")
    
    plt.figure(figsize=(8, 5))
    df[col].dropna().hist(bins=bins, edgecolor="black", log=log)
    plt.title(f"Histogram of {col.title()}")
    plt.xlabel(col.title())
    plt.ylabel("Log(Frequency)" if log else "Frequency")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Load and Inspect Data

# %%
# Load clean data

lulu_df = pd.read_parquet(f"{PATH}/lulu_df_with_topics_00.parquet", engine = 'fastparquet')

# %%
# Examine data

examine_df('lulu dataframe', lulu_df)
# Out:
# Number of records in the lulu dataframe is: 56574
#
#
# Number of features in the lulu dataframe is: 10
#
# The columns in the lulu dataframe are: Index(['post_id', 'timestamp', 'title', 'text', 'score', 'num_comments',
#        'clean_text', 'clean_text_bigram', 'topic_00', 'topic_prob_00'],
#       dtype='object')
#
#
#  Other info about lulu dataframe:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56574 entries, 0 to 56573
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   post_id            56574 non-null  object
#  1   timestamp          56574 non-null  datetime64[ns, UTC]
#  2   title              56574 non-null  object
#  3   text               56574 non-null  object
#  4   score              56574 non-null  int64
#  5   num_comments       56574 non-null  int64
#  6   clean_text         56574 non-null  object
#  7   clean_text_bigram  56574 non-null  object
#  8   topic_00           56574 non-null  int64
#  9   topic_prob_00      56574 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(3), object(5)
# memory usage: 4.3+ MB
# None
#  Basic statistical info about lulu dataframe:
#               score  num_comments      topic_00  topic_prob_00
# count  56574.000000  56574.000000  56574.000000   56574.000000
# mean      23.851805     14.901227      2.289903       0.353285
# std       88.071850     40.710890      5.006362       0.360782
# min        0.000000      0.000000     -1.000000       0.000437
# 25%        1.000000      2.000000     -1.000000       0.079974
# 50%        3.000000      6.000000     -1.000000       0.176474
# 75%       14.000000     13.000000      4.000000       0.553981
# max    11864.000000   1987.000000     18.000000       1.000000
# Sample of records in the lulu dataframe:
#   post_id                 timestamp  \
# 0  eii06s 2020-01-01 12:46:35+00:00
# 1  eijtca 2020-01-01 16:00:56+00:00
# 2  eikiew 2020-01-01 16:59:27+00:00
# 3  eil4bb 2020-01-01 17:46:20+00:00
# 4  ein4er 2020-01-01 20:16:05+00:00
#
#                                          title  \
# 0         Major problem falling down leggings?
# 1                                Tops for yoga
# 2                           ABC Pants - Sizing
# 3  Certain Aligns colours with thicker fabric?
# 4                    Mens Commission Pant Slim
#
#                                                 text  score  num_comments  \
# 0  Hello, over the last year I have been ordering...      0             6
# 1  I have a couple swiftly tech racerbacks for ho...      3             4
# 2  Hey all,\n\nI recently received ABC pants (siz...      1             6
# 3  Hi lemonheads :D\n\nI was wondering if anyone ...      3            11
# 4  Got a giftcard for lulu because my family know...      3             5
#
#                                           clean_text  \
# 0  major problem falling legging hello last year ...
# 1  top yoga couple swiftly tech racerbacks hot yo...
# 2  abc pant sizing hey recently received abc pant...
# 3  certain aligns colour thicker fabric lemonhead...
# 4  men commission pant slim giftcard family know ...
#
#                                    clean_text_bigram  topic_00  topic_prob_00
# 0  major problem falling legging_hello last_year ...        17       1.000000
# 1  top yoga couple swiftly_tech racerbacks hot_yo...        -1       0.156652
# 2  abc_pant sizing_hey recently_received abc_pant...        -1       0.073371
# 3  certain aligns_colour thicker_fabric lemonhead...        -1       0.051949
# 4  men_commission pant_slim giftcard family know_...        -1       0.035935

# %%
# Copy original dataframe

og_lulu_df = lulu_df.copy()

# %% [markdown]
# ## Cleaning to Visualize

# %%
# Drop unnecessary columns for visualization

irr_columns = ['post_id', 'title', 'text', 'score', 'num_comments',
       'clean_text', 'clean_text_bigram', 'topic_prob_00']

vis_df = lulu_df.drop(columns = irr_columns)

# %%
# Rename topic column

vis_df = vis_df.rename(columns={'topic_00': 'topic'})

# %%
# Examine vis_df

examine_df('',vis_df)
# Out:
# Number of records in the  is: 22370
#
#
# Number of features in the  is: 2
#
# The columns in the  are: Index(['timestamp', 'topic'], dtype='object')
#
#
#  Other info about :
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22370 entries, 0 to 56573
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  22370 non-null  datetime64[ns, UTC]
#  1   topic      22370 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(1)
# memory usage: 524.3 KB
# None
#  Basic statistical info about :
#               topic
# count  22370.000000
# mean       5.776039
# std        5.232944
# min        0.000000
# 25%        2.000000
# 50%        4.000000
# 75%        9.000000
# max       18.000000
# Sample of records in the :
#                    timestamp  topic
# 0  2020-01-01 12:46:35+00:00     17
# 11 2020-01-02 18:39:05+00:00     17
# 12 2020-01-02 19:24:16+00:00     10
# 13 2020-01-02 23:45:09+00:00      0
# 15 2020-01-03 04:31:33+00:00      6

# %%
# Create topic labels

topic_labels = {
    0: "Shorts/Leggings",
    1: "Orders/Returns",
    2: "Colors",
    3: "Hoodies/Fleeces",
    4: "Accessories",
    5: "Joggers/Pants",
    6: "Sports Bras",
    7: "Sales/Events",
    8: "Laundry",
    9: "T-Shirts",
    10: "Tanks",
    11: "Discounts/Jobs",
    12: "Community",
    13: "Define Jackets",
    14: "Outerwear",
    15: "Hemming",
    16: "Yoga/Athletic Wear",
    17: "Underwear",
    18: "Skirts/Dresses"
}

# %%
# Define mapping of topic ids to merged categories

merge_map = {
    # # Orders/Returns (1) + Sales/Events (7) → "Orders/Sales"
    # 1: "Sales/Events",
    # 7: "Sales/Events",

    # Define Jackets (13) + Outerwear (14) → "Outerwear/Define"
    13: "Outerwear",
    14: "Outerwear",

    16: "Yoga/Gym Wear",
    18: "Yoga/Gym Wear",
    9: "Yoga/Gym Wear",

    # Tanks (10) + Sports Bras (6) → "Tanks/Sports Bras"
    10: "Tanks/Sports Bras",
    6: "Tanks/Sports Bras",
}

# %%
# Apply merges and drops, keeping original labels for others

vis_df = lulu_df.drop(columns = irr_columns)
vis_df = vis_df.rename(columns={'topic_00': 'topic'})

exc_topics = [-1, 8, 11, 12, 15, 17]

vis_df = vis_df[~vis_df['topic'].isin(exc_topics)]

vis_df["topic_merged"] = vis_df["topic"].map(lambda x: merge_map.get(x, topic_labels[x]))

# %% [markdown]
# ## Visualization Functions

# %%
# Function to plot topic counts seasonally

def plot_topic_counts(df, topic_col="topic_merged", season=None, top_n=6):
    """
    Plot topic frequencies with distinct categorical colors (no legend),
    sorted by frequency (desc), optionally filtered by season,
    with option for top N only, and seasonal emojis in the title.
    """
    # --- Season filter + emoji mapping ---
    emoji_map = {
        "winter": "❄️❄️❄️",
        "spring": "🌸🌸🌸",
        "summer": "☀️☀️☀️",
        "fall": "🍂🍂🍂",
        "autumn": "🍂"
    }

    if season is not None:
        s = str(season).strip().lower()
        if s == "winter":
            months = [12, 1, 2]
        elif s == "spring":
            months = [3, 4, 5]
        elif s == "summer":
            months = [6, 7, 8]
        elif s in ("fall", "autumn"):
            months = [9, 10, 11]
        else:
            raise ValueError("season must be one of {'winter','spring','summer','fall'} or None")
        df_plot = df[df["timestamp"].dt.month.isin(months)]
        season_title = f"{s.capitalize()} {emoji_map[s]}"
        title_suffix = f" — {season_title}"
    else:
        df_plot = df
        title_suffix = ""

    # --- Counts (largest → smallest) ---
    topic_counts = (
        df_plot[topic_col]
        .value_counts()
        .sort_values(ascending=False)
        .rename_axis(topic_col)
        .reset_index(name="count")
    )

    if top_n is not None:
        topic_counts = topic_counts.head(top_n)

    # --- Stable distinct colors tied to merged labels ---
    cats_all = df[topic_col].dropna().astype(str).unique()
    cats_all = sorted(cats_all)
    palette = px.colors.qualitative.Dark24
    color_map = {cat: palette[i % len(palette)] for i, cat in enumerate(cats_all)}

    fig = px.bar(
        topic_counts,
        x=topic_col,
        y="count",
        color=topic_col,
        color_discrete_map=color_map,
        title=f"Topic Frequency{title_suffix}",
        labels={topic_col: "Topic", "count": "Frequency"},
    )

    fig.update_layout(
        showlegend=False,
        xaxis_title="Topic",
        yaxis_title=None
    )
    fig.update_yaxes(showticklabels=False)
    fig.show()

# %% [markdown]
# ## Topic Bar Charts

# %%
# Plot topic counts

plot_topic_counts(vis_df)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="57dbbfbd-699b-48c3-b4b4-514a2034da1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("57dbbfbd-699b-48c3-b4b4-514a2034da1e")) {                    Plotly.newPlot(                        "57dbbfbd-699b-48c3-b4b4-514a2034da1e",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i2","bdata":"rAs="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i2","bdata":"iQo="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orders\u002fReturns","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Orders\u002fReturns","orientation":"v","showlegend":true,"textposition":"auto","x":["Orders\u002fReturns"],"xaxis":"x","y":{"dtype":"i2","bdata":"Rgk="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colors","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Colors","orientation":"v","showlegend":true,"textposition":"auto","x":["Colors"],"xaxis":"x","y":{"dtype":"i2","bdata":"Owk="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga\u002fGym Wear","marker":{"color":"#511CFB","pattern":{"shape":""}},"name":"Yoga\u002fGym Wear","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga\u002fGym Wear"],"xaxis":"x","y":{"dtype":"i2","bdata":"NAk="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hoodies\u002fFleeces","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Hoodies\u002fFleeces","orientation":"v","showlegend":true,"textposition":"auto","x":["Hoodies\u002fFleeces"],"xaxis":"x","y":{"dtype":"i2","bdata":"xgc="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222," ...

# %% [markdown]
# ## Spring

# %%
# Plot topic counts for spring

plot_topic_counts(vis_df, season = 'spring')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="d21fd9be-0733-446b-9bd1-ef548210f142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d21fd9be-0733-446b-9bd1-ef548210f142")) {                    Plotly.newPlot(                        "d21fd9be-0733-446b-9bd1-ef548210f142",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i2","bdata":"MAM="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i2","bdata":"wQI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colors","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Colors","orientation":"v","showlegend":true,"textposition":"auto","x":["Colors"],"xaxis":"x","y":{"dtype":"i2","bdata":"dQI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga\u002fGym Wear","marker":{"color":"#511CFB","pattern":{"shape":""}},"name":"Yoga\u002fGym Wear","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga\u002fGym Wear"],"xaxis":"x","y":{"dtype":"i2","bdata":"bwI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orders\u002fReturns","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Orders\u002fReturns","orientation":"v","showlegend":true,"textposition":"auto","x":["Orders\u002fReturns"],"xaxis":"x","y":{"dtype":"i2","bdata":"8AE="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joggers\u002fPants","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Joggers\u002fPants","orientation":"v","showlegend":true,"textposition":"auto","x":["Joggers\u002fPants"],"xaxis":"x","y":{"dtype":"i2","bdata":"ewE="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %% [markdown]
# ## Summer

# %%
# Plot topic counts for spring

plot_topic_counts(vis_df, season = 'summer')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="1c95aaa0-536f-40c0-9010-9f674e094491" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1c95aaa0-536f-40c0-9010-9f674e094491")) {                    Plotly.newPlot(                        "1c95aaa0-536f-40c0-9010-9f674e094491",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i2","bdata":"ggM="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i2","bdata":"VAM="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orders\u002fReturns","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Orders\u002fReturns","orientation":"v","showlegend":true,"textposition":"auto","x":["Orders\u002fReturns"],"xaxis":"x","y":{"dtype":"i2","bdata":"AwM="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga\u002fGym Wear","marker":{"color":"#511CFB","pattern":{"shape":""}},"name":"Yoga\u002fGym Wear","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga\u002fGym Wear"],"xaxis":"x","y":{"dtype":"i2","bdata":"wAI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colors","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Colors","orientation":"v","showlegend":true,"textposition":"auto","x":["Colors"],"xaxis":"x","y":{"dtype":"i2","bdata":"pgI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accessories","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Accessories"],"xaxis":"x","y":{"dtype":"i2","bdata":"LAI="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333333 ...

# %% [markdown]
# ## Fall

# %%
# Plot topic counts for spring

plot_topic_counts(vis_df, season = 'fall')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="eee3fdca-495c-4a81-9b2d-4b9c50a2550b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eee3fdca-495c-4a81-9b2d-4b9c50a2550b")) {                    Plotly.newPlot(                        "eee3fdca-495c-4a81-9b2d-4b9c50a2550b",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i2","bdata":"bwI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga\u002fGym Wear","marker":{"color":"#511CFB","pattern":{"shape":""}},"name":"Yoga\u002fGym Wear","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga\u002fGym Wear"],"xaxis":"x","y":{"dtype":"i2","bdata":"SgI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i2","bdata":"HwI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hoodies\u002fFleeces","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Hoodies\u002fFleeces","orientation":"v","showlegend":true,"textposition":"auto","x":["Hoodies\u002fFleeces"],"xaxis":"x","y":{"dtype":"i2","bdata":"\u002fwE="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joggers\u002fPants","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Joggers\u002fPants","orientation":"v","showlegend":true,"textposition":"auto","x":["Joggers\u002fPants"],"xaxis":"x","y":{"dtype":"i2","bdata":"\u002fQE="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Outerwear","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"Outerwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Outerwear"],"xaxis":"x","y":{"dtype":"i2","bdata":"5QE="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %% [markdown]
# ## Winter

# %%
# Plot topic counts for spring

plot_topic_counts(vis_df, season = 'winter')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="ff9ef11b-17f8-4441-8a48-b3865ce03a7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ff9ef11b-17f8-4441-8a48-b3865ce03a7b")) {                    Plotly.newPlot(                        "ff9ef11b-17f8-4441-8a48-b3865ce03a7b",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hoodies\u002fFleeces","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Hoodies\u002fFleeces","orientation":"v","showlegend":true,"textposition":"auto","x":["Hoodies\u002fFleeces"],"xaxis":"x","y":{"dtype":"i2","bdata":"wwI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i2","bdata":"uQI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orders\u002fReturns","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Orders\u002fReturns","orientation":"v","showlegend":true,"textposition":"auto","x":["Orders\u002fReturns"],"xaxis":"x","y":{"dtype":"i2","bdata":"egI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colors","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Colors","orientation":"v","showlegend":true,"textposition":"auto","x":["Colors"],"xaxis":"x","y":{"dtype":"i2","bdata":"PwI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joggers\u002fPants","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Joggers\u002fPants","orientation":"v","showlegend":true,"textposition":"auto","x":["Joggers\u002fPants"],"xaxis":"x","y":{"dtype":"i2","bdata":"LgI="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i2","bdata":"JwI="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222," ...

# %% [markdown]
# ## Topic Bar Chart Animation

# %%
# Function to create animation

def animate_topics_over_time(df, topic_col="topic_merged", top_n=None):
    """
    Create a month-by-month animated bar chart of topic frequencies.
    """
    # --- Prepare monthly buckets ---
    monthly = (
        df.assign(month=df["timestamp"].dt.to_period("M").dt.to_timestamp())
          .groupby(["month", topic_col], as_index=False)
          .size()
          .rename(columns={"size": "count"})
    )

    # --- Optionally restrict to top-N topics overall (stable across frames) ---
    if top_n is not None:
        top_topics = (
            monthly.groupby(topic_col)["count"]
                   .sum()
                   .sort_values(ascending=False)
                   .head(top_n)
                   .index
        )
        monthly = monthly[monthly[topic_col].isin(top_topics)]

    # --- Stable category order (by overall frequency, desc) for consistent x ordering ---
    overall_order = (
        monthly.groupby(topic_col)["count"]
               .sum()
               .sort_values(ascending=False)
               .index.tolist()
    )

    # --- Distinct color map (non-spectral), tied to topic labels ---
    cats_all = sorted(monthly[topic_col].dropna().astype(str).unique())
    palette = px.colors.qualitative.Dark24  # distinct colors
    color_map = {cat: palette[i % len(palette)] for i, cat in enumerate(cats_all)}

    # --- Fix y-range across frames so bars don't "jump" visually ---
    y_max = (monthly["count"].max() or 1) * 1.05

    # --- Build animation ---
    # Use formatted month strings for cleaner slider labels
    monthly["month_label"] = monthly["month"].dt.strftime("%Y-%m")

    fig = px.bar(
        monthly,
        x=topic_col,
        y="count",
        color=topic_col,
        animation_frame="month_label",
        category_orders={topic_col: overall_order},
        color_discrete_map=color_map,
        title="Topic Frequency — Monthly Animation ❄️🌸☀️🍂",
        labels={topic_col: "Topic", "count": "Frequency"},
        range_y=[0, y_max],
    )

    # Tidy aesthetics: no legend, hide y-axis tick labels (relative emphasis)
    fig.update_layout(
        showlegend=False,
        xaxis_title="Topic",
        yaxis_title=None,
        margin=dict(l=20, r=20, t=60, b=20)
    )
    fig.update_yaxes(showticklabels=False)

    # Smoother animation settings
    fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 600  # ms per frame
    fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 300

    fig.show()

# %%
# Animate all topics month-by-month

animate_topics_over_time(vis_df)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="e12b4fdb-c416-4310-9f82-393269fe483d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e12b4fdb-c416-4310-9f82-393269fe483d")) {                    Plotly.newPlot(                        "e12b4fdb-c416-4310-9f82-393269fe483d",                        [{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shorts\u002fLeggings","marker":{"color":"#750D86","pattern":{"shape":""}},"name":"Shorts\u002fLeggings","orientation":"v","showlegend":true,"textposition":"auto","x":["Shorts\u002fLeggings"],"xaxis":"x","y":{"dtype":"i1","bdata":"EA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tanks\u002fSports Bras","marker":{"color":"#EB663B","pattern":{"shape":""}},"name":"Tanks\u002fSports Bras","orientation":"v","showlegend":true,"textposition":"auto","x":["Tanks\u002fSports Bras"],"xaxis":"x","y":{"dtype":"i1","bdata":"Cg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orders\u002fReturns","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"Orders\u002fReturns","orientation":"v","showlegend":true,"textposition":"auto","x":["Orders\u002fReturns"],"xaxis":"x","y":{"dtype":"i1","bdata":"Cg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colors","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Colors","orientation":"v","showlegend":true,"textposition":"auto","x":["Colors"],"xaxis":"x","y":{"dtype":"i1","bdata":"Bw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga\u002fGym Wear","marker":{"color":"#511CFB","pattern":{"shape":""}},"name":"Yoga\u002fGym Wear","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga\u002fGym Wear"],"xaxis":"x","y":{"dtype":"i1","bdata":"BA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hoodies\u002fFleeces","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Hoodies\u002fFleeces","orientation":"v","showlegend":true,"textposition":"auto","x":["Hoodies\u002fFleeces"],"xaxis":"x","y":{"dtype":"i1","bdata":"Ag=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accessories","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Accessories"],"xaxis":"x","y":{"dtype":"i1","bdata":"Ag=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=2020-01\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joggers\u002fPants","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Joggers\u002fPants","orientation":"v","showlegend":true,"textposition":"auto","x":["Joggers\u002fPants"],"xaxis":"x","y":{"dtype":"i1","bdata":"Fg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Topic=%{x}\u003cbr\u003emonth_label=202 ...
