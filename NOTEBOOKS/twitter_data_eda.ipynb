# %% [markdown]
# ## Preliminaries

# %%
# Imports

from dotenv import load_dotenv
import os
import praw
from praw.models import MoreComments
import matplotlib as plt
import re, pandas as pd
import numpy as np
import time
from datetime import datetime, timezone, timedelta

# %%
# Set user's data path

PATH = f"C:/Users/emshe/Desktop/BRAINSTATION/LULULEMON/DATA/TWEETS/archive/nikelululemonadidas_tweets.jsonl"

# %% [markdown]
# ## Helper functions

# %%
# Function to clean text

def clean_text(s: str | None) -> str | None:
    
    '''
    Clean string by substituting spaces for problematic characters
    '''
    
    if s is None:
        return None
    s = re.sub(r"\s+", " ", s).strip()
    return s

# %%
# Function to get datetime from UTC timestamp

def dt_from_utc(ts: float) -> pd.Timestamp:

    '''
    Returns pd.datetime object (still in UTC)
    '''
    
    return pd.to_datetime(ts, unit="s", utc=True)

# %%
# Function to examine dataframes

def examine_df(name,df,
               include_stats = True,
               include_sample = True):
    
    """
    Check basic info about a dataframe df
    """
    
    print(f"\n\nNumber of records in the {name} is: {len(df)}\n")
    print(f"\nNumber of features in the {name} is: {len(df.columns)}\n")
    print(f"The columns in the {name} are: {df.columns}\n")
    print(f"\n Other info about {name}:\n")
    display(df.info())
    if include_stats == True:
        print(f'\n Basic statistical info about {name}:\n')
        display(df.describe())
    if include_sample == True:
        print(f"\n\nSample of records in the {name}:")
        display(df.head(5))

# %% [markdown]
# ## Load and Inspect Data

# %%
# Load twitter data

tweets_df = pd.read_json(PATH,lines=True)

# %%
# Examine twitter data

examine_df('Twitter dataframe', tweets_df)
# Out:
# Number of records in the Twitter dataframe is: 175078
#
#
# Number of features in the Twitter dataframe is: 32
#
# The columns in the Twitter dataframe are: Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive', 'lang',
#        'retweeted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status_permalink', 'quoted_status', 'withheld_in_countries'],
#       dtype='object')
#
#
#  Other info about Twitter dataframe:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175078 entries, 0 to 175077
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   created_at                 175078 non-null  datetime64[ns, UTC]
#  1   id                         175078 non-null  int64
#  2   id_str                     175078 non-null  int64
#  3   full_text                  175078 non-null  object
#  4   truncated                  175078 non-null  bool
#  5   display_text_range         175078 non-null  object
#  6   entities                   175078 non-null  object
#  7   extended_entities          42397 non-null   object
#  8   source                     175078 non-null  object
#  9   in_reply_to_status_id      65499 non-null   float64
#  10  in_reply_to_status_id_str  65499 non-null   float64
#  11  in_reply_to_user_id        74424 non-null   float64
#  12  in_reply_to_user_id_str    74424 non-null   float64
#  13  in_reply_to_screen_name    74424 non-null   object
#  14  user                       175078 non-null  object
#  15  geo                        275 non-null     object
#  16  coordinates                275 non-null     object
#  17  place                      5727 non-null    object
#  18  contributors               0 non-null       float64
#  19  is_quote_status            175078 non-null  bool
#  20  retweet_count              175078 non-null  int64
#  21  favorite_count             175078 non-null  int64
#  22  favorited                  175078 non-null  bool
#  23  retweeted                  175078 non-null  bool
#  24  possibly_sensitive         61050 non-null   float64
#  25  lang                       175078 non-null  object
#  26  retweeted_status           69025 non-null   object
#  27  quoted_status_id           14337 non-null   float64
#  28  quoted_status_id_str       14337 non-null   float64
#  29  quoted_status_permalink    14337 non-null   object
#  30  quoted_status              11268 non-null   object
#  31  withheld_in_countries      11602 non-null   object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(8), int64(4), object(15)
# memory usage: 38.1+ MB
# None
#  Basic statistical info about Twitter dataframe:
#                  id        id_str  in_reply_to_status_id  \
# count  1.750780e+05  1.750780e+05           6.549900e+04
# mean   1.459910e+18  1.459910e+18           1.458020e+18
# std    9.343355e+15  9.343355e+15           1.857045e+16
# min    1.443818e+18  1.443818e+18           5.785303e+16
# 25%    1.452045e+18  1.452045e+18           1.449183e+18
# 50%    1.459229e+18  1.459229e+18           1.459275e+18
# 75%    1.468982e+18  1.468982e+18           1.467672e+18
# max    1.477172e+18  1.477172e+18           1.477171e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               6.549900e+04         7.442400e+04
# mean                1.458020e+18         2.855240e+17
# std                 1.857045e+16         5.160189e+17
# min                 5.785303e+16         1.200000e+01
# 25%                 1.449183e+18         2.566584e+08
# 50%                 1.459275e+18         4.158594e+08
# 75%                 1.467672e+18         4.015386e+09
# max                 1.477171e+18         1.475984e+18
#
#        in_reply_to_user_id_str  contributors  retweet_count  favorite_count  \
# count             7.442400e+04           0.0  175078.000000   175078.000000
# mean              2.855240e+17           NaN    2175.394538        4.640395
# std               5.160189e+17           NaN    5476.268498      361.181852
# min               1.200000e+01           NaN       0.000000        0.000000
# 25%               2.566584e+08           NaN       0.000000        0.000000
# 50%               4.158594e+08           NaN       0.000000        0.000000
# 75%               4.015386e+09           NaN      43.000000        1.000000
# max               1.475984e+18           NaN  109237.000000   115514.000000
#
#        possibly_sensitive  quoted_status_id  quoted_status_id_str
# count        61050.000000      1.433700e+04          1.433700e+04
# mean             0.032039      1.456705e+18          1.456705e+18
# std              0.176106      4.094802e+16          4.094802e+16
# min              0.000000      7.265985e+16          7.265985e+16
# 25%              0.000000      1.452712e+18          1.452712e+18
# 50%              0.000000      1.461536e+18          1.461536e+18
# 75%              0.000000      1.468979e+18          1.468979e+18
# max              1.000000      1.477156e+18          1.477156e+18
# Sample of records in the Twitter dataframe:
#                  created_at                   id               id_str  \
# 0 2021-10-01 08:25:03+00:00  1443854459625431000  1443854459625431040
# 1 2021-10-01 07:37:16+00:00  1443842433641558000  1443842433641558016
# 2 2021-10-01 10:01:58+00:00  1443878848211439600  1443878848211439616
# 3 2021-10-01 07:41:45+00:00  1443843563108905000  1443843563108904960
# 4 2021-10-01 06:22:08+00:00  1443823529296867300  1443823529296867328
#
#                                            full_text  truncated  \
# 0  #ad The Nike Women's Air More Uptempo 96 'Whit...      False
# 1  @_christiankeith @d1vetsam @KicksFinder They a...      False
# 2  Proof @LaserShip is stealing. I work from home...      False
# 3  RT @pyleaks: *LEAK ALERT*: The next Supreme x ...      False
# 4  RT @SneakerScouts: #ad The Space Jam x Nike Le...      False
#
#   display_text_range                                           entities  \
# 0           [0, 146]  {'hashtags': [{'text': 'ad', 'indices': [0, 3]...
# 1           [40, 73]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 106]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 140]  {'hashtags': [{'text': 'ad', 'indices': [19, 2...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1443854458404941800, 'id_str...
# 1                                                NaN
# 2  {'media': [{'id': 1443878844923105300, 'id_str...
# 3                                                NaN
# 4                                                NaN
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://www.hootsuite.com" rel="nofol...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...           1.443836e+18
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/android" ...                    NaN
# 4  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
#
#    ...  favorited  retweeted  possibly_sensitive lang  \
# 0  ...      False      False                 0.0   en
# 1  ...      False      False                 NaN   en
# 2  ...      False      False                 0.0   en
# 3  ...      False      False                 NaN   en
# 4  ...      False      False                 NaN   en
#
#                                     retweeted_status quoted_status_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  {'created_at': 'Wed Sep 29 15:40:11 +0000 2021...              NaN
# 4  {'created_at': 'Thu Sep 30 16:10:08 +0000 2021...              NaN
#
#   quoted_status_id_str quoted_status_permalink  quoted_status  \
# 0                  NaN                     NaN            NaN
# 1                  NaN                     NaN            NaN
# 2                  NaN                     NaN            NaN
# 3                  NaN                     NaN            NaN
# 4                  NaN                     NaN            NaN
#
#    withheld_in_countries
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 32 columns]

# %%
tweets_df['created_at'].describe()
# Out:
# count                                 175078
# mean     2021-11-14 15:44:45.898999808+00:00
# min                2021-10-01 06:00:43+00:00
# 25%                2021-10-23 22:51:26+00:00
# 50%                2021-11-12 18:39:36+00:00
# 75%         2021-12-09 16:33:31.500000+00:00
# max                2022-01-01 06:58:15+00:00
# Name: created_at, dtype: object
