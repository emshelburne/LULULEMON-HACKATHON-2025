# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\karni\OneDrive\Documents\GitHub\LULULEMON-HACKATHON-2025\data\lululemon_dummy_5000.csv') # change the path to where you saved the CSV file
df.head()
# Out:
#    user_id session_id            timestamp        action product_id  \
# 0      181  sess_2824  2025-08-02T03:19:00      purchase     MSH033
# 1      175  sess_7912  2025-08-02T10:42:00  view_product     WSB021
# 2      171  sess_4257  2025-08-30T13:50:00        search        NaN
# 3      157  sess_5557  2025-08-01T07:05:00   add_to_cart     MHD099
# 4      127  sess_6514  2025-08-05T15:38:00  view_product     MHD099
#
#                  product_name       category  price_usd size_selected  \
# 0              Surge Short 6"   Men > Shorts       68.0             S
# 1        Energy Bra Long Line   Women > Bras       58.0             S
# 2                         NaN            NaN        NaN           NaN
# 3  City Sweat Pullover Hoodie  Men > Hoodies      108.0             M
# 4  City Sweat Pullover Hoodie  Men > Hoodies      108.0            XS
#
#   color_selected payment_method   device                      location  \
# ...
